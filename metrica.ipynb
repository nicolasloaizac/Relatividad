# %%
import sympy as sp

# %%
teta = sp.symbols('theta')
R = sp.Matrix([[sp.cos(teta) , sp.sin(teta)] , [-sp.sin(teta) , sp.cos(teta)]])

# g = sp.Matrix([[1,2] , [3,1]])

g = sp.diag(*[8,8])

# %%
R
# Out:
# Matrix([
# [ cos(theta), sin(theta)],
# [-sin(theta), cos(theta)]])

# %%
g
# Out:
# Matrix([
# [8, 0],
# [0, 8]])
