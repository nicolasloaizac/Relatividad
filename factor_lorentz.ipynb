# %%
{
 "cell_type": "code",
 "execution_count": null,
 "metadata": {},
 "outputs": [],
 "source": [
  "import numpy as np\n",
  "import matplotlib.pyplot as plt\n",
  "\n",
  "# Define speed of light and beta parameter\n",
  "c = 1  # units where c=1\n",
  "beta = np.logspace(-6, -0.0001, 500)  # velocities as fraction of c\n",
  "\n",
  "# Lorentz factor\n",
  "gamma = 1 / np.sqrt(1 - beta**2)\n",
  "\n",
  "# Plot log-log graph\n",
  "plt.figure(figsize=(6,4))\n",
  "plt.loglog(beta, gamma)\n",
  "plt.xlabel(r'\\beta = v/c')\n",
  "plt.ylabel(r'\\gamma (Lorentz factor)')\n",
  "plt.title('Log-Log plot of Lorentz factor')\n",
  "plt.grid(True, which='both', ls='--')\n",
  "plt.show()\n"
 ]
}
